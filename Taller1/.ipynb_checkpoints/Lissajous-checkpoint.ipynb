# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# $$ x = Asin(\omega_x t) $$
# $$ y = Asin(\omega_y t + \delta) $$

# %%
A = 1
N=100
wx = wy = 1
n = 5
delta = [0, np.pi/4, np.pi/2]
nx = [1,2,3,4,5]

t = np.linspace(0,2*np.pi,N)

fr = [(1,1),(1,2),(1,3),(1,4),(1,5),(2,2),(2,3),(2,4),(2,5),(3,3),(3,4),(3,5),(4,4),(4,5),(5,5)]

# %%
y = A*np.sin(wy*t)
x = A*np.sin(wx*t)

# %%
fig = plt.figure(figsize=(6,6) )
ind = 0

for j in range(len(fr)):
    wx = fr[j][0]
    wy = fr[j][1]
    y = A*np.sin(wy*t + delta[0])
    x = A*np.sin(wx*t)
    ind+=1
    ax = fig.add_subplot(5,3,ind)
    ax.plot(x,y)
    ax.set_aspect('equal')
    ax.axis("off")
# Out:
# <img src="data:image/png;base64,..." width="599.8079816953131">

# %%
fig = plt.figure(figsize=(6,6) )
ind = 0

for j in range(len(fr)):
    wx = fr[j][0]
    wy = fr[j][1]
    y = A*np.sin(wy*t + delta[1])
    x = A*np.sin(wx*t)
    ind+=1
    ax = fig.add_subplot(5,3,ind)
    ax.plot(x,y)
    ax.set_aspect("equal")
    ax.axis("off")
# Out:
# <img src="data:image/png;base64,..." width="599.8079816953131">

# %%
fig = plt.figure(figsize=(6,6) )
ind = 0

for j in range(len(fr)):
    wx = fr[j][0]
    wy = fr[j][1]
    y = A*np.sin(wy*t + delta[2])
    x = A*np.sin(wx*t)
    ind+=1
    ax = fig.add_subplot(5,3,ind)
    ax.plot(x,y)
    ax.set_aspect("equal")
    ax.axis("off")
# Out:
# <img src="data:image/png;base64,..." width="599.8079816953131">
