# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
def SegundaDerivadaCentral(x,f,h):
    SecDerivada= (f(x+h)-(2*f(x))+ f(x-h))/(h**2)
    return SecDerivada

# %%
x= np.linspace(-10.0,10.0,400)
expmenosxalados= lambda x: ((1+np.exp(-x**2))**-0.5)
print(SegundaDerivadaCentral(x,expmenosxalados,0.05))
# Out:
# [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
# ...

# %%
SegDerivadaC = SegundaDerivadaCentral(x,expmenosxalados,0.05)
plt.figure(figsize=(7,3))
plt.plot(x,SegDerivadaC)

plt.xlim(-10,10)
plt.ylim(-0.4,0.4)

ax.set_aspect('equal', adjustable='box')
# Out:
# <img src="data:image/png;base64,..." width="700">
